# %%
 import pandas as pd

# %%
df = pd.read_excel('PAC_2018_06.xlsx')
df.head()
# Out:
#    idn_empreendimento  idn_digs  \
# 0                1311      1001
# 1                1319      6002
# 2                1337      1004
# 3                1354      2000
# 4                1356      2000
#
#                                           dsc_titulo  investimento_total  \
# 0  Adequação Linha Férrea de Barra Mansa/RJ e con...        1.694328e+08
# 1                         Adutora São Francisco - SE        1.453800e+08
# 2  Aeroporto Porto Alegre - Ampliação da Pista de...                 NaN
# 3     Inventário - Bacia do Rio Trombetas - AM PA RR        2.461200e+07
# 4             Usina Hidrelétrica - Baixo Iguaçu - PR        1.621994e+09
#
#      sig_uf                                     txt_municipios  \
# 0        RJ                   BARRA MANSA/RJ, VOLTA REDONDA/RJ
# 1        SE                                         ARACAJU/SE
# 2        RS                                    PORTO ALEGRE/RS
# 3  AM PA RR  ALENQUER/PA, CAROEBE/RR, NHAMUNDÁ/AM, ÓBIDOS/P...
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format
df.head(2)
# Out:
#    idn_empreendimento  idn_digs  \
# 0                1311      1001
# 1                1319      6002
#
#                                           dsc_titulo  investimento_total  \
# 0  Adequação Linha Férrea de Barra Mansa/RJ e con...        169432779.95
# 1                         Adutora São Francisco - SE        145380000.00
#
#   sig_uf                    txt_municipios txt_executores  \
# 0     RJ  BARRA MANSA/RJ, VOLTA REDONDA/RJ           DNIT
# 1     SE                        ARACAJU/SE         Estado
#
#                                            dsc_orgao  idn_estagio  dat_ciclo  \
# 0  Ministério dos Transportes, Portos e Aviação C...           70 2018-06-30
# 1                  Ministério da Integração Nacional           70 2018-06-30
#
#   dat_selecao dat_conclusao_revisada obra_latitude obra_longitude emblematica  \
# 0         NaT                    NaT           NaN            NaN         NaN
# ...

# %%
df.dtypes
# Out:
# idn_empreendimento                 int64
# idn_digs                           int64
# dsc_titulo                        object
# investimento_total               float64
# sig_uf                            object
# txt_municipios                    object
# txt_executores                    object
# dsc_orgao                         object
# idn_estagio                        int64
# dat_ciclo                 datetime64[ns]
# dat_selecao               datetime64[ns]
# dat_conclusao_revisada    datetime64[ns]
# obra_latitude                     object
# obra_longitude                    object
# emblematica                       object
# observacao                        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33502 entries, 0 to 33501
# Data columns (total 16 columns):
# idn_empreendimento        33502 non-null int64
# idn_digs                  33502 non-null int64
# dsc_titulo                33502 non-null object
# investimento_total        27752 non-null float64
# sig_uf                    33502 non-null object
# txt_municipios            33134 non-null object
# txt_executores            33028 non-null object
# dsc_orgao                 33502 non-null object
# idn_estagio               33502 non-null int64
# dat_ciclo                 33502 non-null datetime64[ns]
# dat_selecao               30382 non-null datetime64[ns]
# dat_conclusao_revisada    15060 non-null datetime64[ns]
# obra_latitude             31344 non-null object
# obra_longitude            31344 non-null object
# emblematica               140 non-null object
# observacao                7199 non-null object
# dtypes: datetime64[ns](3), float64(1), int64(3), object(9)
# ...

# %%
##Verificar valores nulos na colina investimento_total        
df['investimento_total'].isnull()
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12        True
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23        True
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 33472     True
# 33473     True
# 33474     True
# 33475     True
# 33476     True
# 33477     True
# 33478     True
# 33479     True
# 33480     True
# 33481     True
# 33482     True
# 33483     True
# 33484     True
# 33485     True
# 33486     True
# 33487     True
# 33488     True
# 33489     True
# 33490    False
# 33491     True
# 33492     True
# 33493     True
# 33494     True
# 33495    False
# 33496     True
# 33497    False
# 33498    False
# ...

# %%
## quantos valores nulos na mesma coluna?
df['investimento_total'].isnull().sum()
# Out:
# 5750

# %%
# onde estao as obras com valores de investimento == 0
df[df['investimento_total'].isnull() == True]['sig_uf'].value_counts()
# Out:
# MG                                  708
# PE                                  507
# PA                                  473
# RS                                  417
# GO                                  375
# CE                                  371
# SP                                  356
# BA                                  346
# PR                                  315
# MA                                  213
# RJ                                  200
# PB                                  196
# AM                                  158
# AL                                  158
# PI                                  122
# RN                                  108
# SC                                  105
# RO                                   80
# ES                                   75
# TO                                   75
# DF                                   67
# MS                                   66
# SE                                   65
# ...

# %%
df[df['sig_uf']=='BR']
# Out:
#        idn_empreendimento  idn_digs  \
# 374                  9509      2003
# 7617                35633      2003
# 11615               44778      1002
# 11660               44877      1006
# 11661               44878      1006
# 13480               47186      1002
# 13482               47188      1004
# 13485               47192      1006
# 13486               47193      1006
# 13487               47195      1006
# 13488               47198      1006
# 13489               47200      1006
# 14058               56018      1002
# 14059               56021      1002
# 19928               62631      1002
# 28927               78196      1004
# 28950               84974      2003
# 28951               84975      2003
# 28952               84976      2003
# 28955               85010      1002
# 29304               85486      3000
# 29305               85488      3000
# 29306               85489      3000
# 29307               85492      3000
# 30205               86903      1007
# ...

# %%
df[df['sig_uf']=='BR'].shape
# Out:
# (62, 16)

# %%
# investimento total das obras com sig_uf == BR
df[df['sig_uf']=='BR']['investimento_total'].sum()
# Out:
# 224144425979.09998

# %%
df[df['sig_uf']=='DF']['investimento_total'].sum()
# Out:
# 3357602020.3599997

# %%
# Qual a obra mais cara do df?
df[df['sig_uf']=='DF']['investimento_total'].max()
# deu so o valor, vamos fazer denovo
# Out:
# 906462100.0

# %%
# Qual a obra mais cara do df?
# criar um dataframe pro Distrito Federal
df_df = df[df['sig_uf']=='Df'].copy()

# %%
df_df[df_df['investimento_total']] == df_df['investimento_total'].max()
# Out:
# Series([], Name: investimento_total, dtype: bool)
